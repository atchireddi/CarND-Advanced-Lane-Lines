# %%
import numpy as np
import cv2
import glob
import pickle
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
def pipeline(img, s_thresh=(170, 255), sx_thresh=(20, 100)):
    
    global cnt
    
    img = np.copy(img)
  
     # hls
    hlsc = cv2.cvtColor(img, cv2.COLOR_RGB2HLS).astype(np.float)
    hls = hlsc[:,:,0]
    hls = np.append(hls, hlsc[:,:,1], 0)
    hls = np.append(hls, hlsc[:,:,2], 0)

    # hsv
    hsvc = cv2.cvtColor(img, cv2.COLOR_RGB2HSV).astype(np.float)
    hsv = hsvc[:,:,0]
    hsv = np.append(hsv, hsvc[:,:,1], 0)
    hsv = np.append(hsv, hsvc[:,:,2], 0)

    # Merge
    p = np.append(hls,hsv,1)

    p1 = p  # make a copy
    
    # binary image
    binary_output = np.zeros_like(p)
    binary_output1 = np.zeros_like(p)
    
    binary_output[ (p>80) & (p<=255) ] = 1
    binary_output1[ (p>130) & (p<=255) ] = 1

    
    # Filter
    p[p>80] = 255
    p1[p>130] = 255

    # Merge diff threshold
    pb = np.append(p, p1,1)
    binary = np.append(binary_output, binary_output1,1)
    
    binary_final = np.zeros((720,1280))
    
    
    print(s.shape)
    print(v.shape)
    
    binary_final[ (s>80) & (v>130) ] = 1
    
    pbf = np.append(binary_final, binary_final,1)
    pbf = np.append(pbf, pbf,1)
    
    binary = np.append(binary, pbf, 0)
    
    # mpimg.imsave('./pipeline_outputs/colorGrad/hls_'+str(cnt)+'.jpg', pb, cmap='gray')
    mpimg.imsave('./pipeline_outputs/colorGrad/binary_'+str(cnt)+'.jpg', binary, cmap='gray')
    
    return binary_output

# %%
# Place holder for live processing

cnt = 0  # global counter
images = glob.glob('./video2ImageSample/projectVideoImage_*.jpg')


for image in sorted(images):
    img = mpimg.imread(image)
    pipeline(img)
    cnt +=1
# Out:
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# (720, 5120)
# (720, 1280)
# (720, 1280)
# ...

# %%
img = mpimg.imread('./video2Image/projectVideoImage_1.jpg')
plt.imshow(img)
